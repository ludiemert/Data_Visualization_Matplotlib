# %%
import numpy as np

# %%
# criar valores aleatorios para trab em cima deles
x = np.linspace(0, 5, 11)

# %%
x # cria uma serie com 11 valres, igualmente distribuidos entre 0 e 5
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
# cria uma funcao y => com o linspace eu digo que meu y = x ** 2
y = x ** 2

# %%
# import matplotlib
import matplotlib.pyplot as plt

# ideal usar matplotlib inline para fazer a linha

# %%
# iniciando o plot
plt.plot(x, y, "red")
# gerou um grafico eixo x e y


# os graficos levam o nome de EIXO
# a caixa imaginaria leva o nome de figer

# os dados estao no eixo dentro da figer

# %%
# mostrar eixo x e eixo y
plt.plot(x,y, "red")
plt.xlabel("Eixo x")
plt.ylabel("Eixo y")
plt.title("Titulo")
# Out:
# Text(0.5, 1.0, 'Titulo')

# %%
# method subplot => cria dois eixos dentro de uma mesma figer
# dentro dessa cx cria varios eixos diferentes e coloque varios eixos diferentes

plt.subplot(1, 2, 1)

# Call signatures::

#   subplot(nrows, ncols, index, **kwargs)
#   subplot(pos, **kwargs)
#   subplot(**kwargs)
#   subplot(ax)

plt.plot(x, y, "r--") # quero cor vermelha tracejada
plt.subplot(1, 2, 2) # passando outro eixo
plt.plot(y, x, "g*-") # passando greem com * e traco

# graficos com eixos diferentes

# %%
 # Orientacao a objetos no Matplotlib

# iniciando extanciando a figuer => que vai ter todos os dados => fig

fig = plt.figure()

# a figer ja existe agora add um eixo, passo uma lista com 4 valores
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
# 4 valores que diz => meu eixo vai comecar se posicionar 10% apartir da esquerda,
# 0.1 da parte de baixo do grafico => inferior, ele vai preencher 80% da figer => largura e vai ter 80% de altura da figer => altura

axes.plot(x, y, "blue")
# add dados, como nao tem outro dados para outro grafico ele gera um grafico qualquer, veja


# mais dados orientado a objeto
axes.set_xlabel("Label x")
axes.set_ylabel("Label y")
axes.set_title("Titulo")
# Out:
# Text(0.5, 1.0, 'Titulo')

# %%
# com 2 eixos e 2 graficos

fig = plt.figure()

# a figer ja existe agora add um eixo, passo uma lista com 4 valores
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
# 4 valores que diz => meu eixo vai comecar se posicionar 10% apartir da esquerda,
# 0.1 da parte de baixo do grafico => inferior, ele vai preencher 80% da figer => largura e vai ter 80% de altura da figer => altura

axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) 

axes.plot(x, y, "blue")
# add dados, como nao tem outro dados para outro grafico ele gera um grafico qualquer, veja

# mais dados orientado a objeto
axes.set_xlabel("Label x")
axes.set_ylabel("Label y")
axes.set_title("Titulo")



axes2.plot(x, y, "red")
# add dados, como nao tem outro dados para outro grafico ele gera um grafico qualquer, veja

# mais dados orientado a objeto
axes2.set_xlabel("Label x2")
axes2.set_ylabel("Label y2")
axes2.set_title("Titulo2")
# Out:
# Text(0.5, 1.0, 'Titulo2')

# %%
# posiciona o a figer maior no grafico maior e posiciona o outro
# varias opcoes  de manipulacao de grafico

# %%
# FUNCAO SUBPLOTS()
# Permite que crie figuras e eixos de diversar formas com diversas configuracoes, eh semelhante a subplot, a dif que ela da mais 
# acessos mais complexos

# vamos iniciar desacoplamento de tuplas
# () => uma lista leva o nome de TUPLA

(1, 2) # tupla
# Out:
# (1, 2)

# %%
type((1, 2))
# Out:
# tuple

# %%
# Desacoplamento de TUPLAS
a, b = (1, 2)

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
# retornar multiplos valores usamos tuplas
# primeiro elemento eh uma Figure e o segundo elemento eh um eixo

plt.subplots()

# isso eh uma tupla => (<Figure size 640x480 with 1 Axes>, <Axes: >)

# geralmente o comando eh =>  fig, ax = plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
# start a trab com o novo eixo
fig, ax = plt.subplots()

# %%
# agora com o subplote podemos passar parametros para os graficos
fig, ax = plt.subplots()
ax.plot(x, y, "r--")
ax.set_title("Titulo Subplots")
# Out:
# Text(0.5, 1.0, 'Titulo Subplots')

# %%
# criar uma lista com 2 elementos
fig, ax = plt.subplots(nrows=1, ncols=2)  # 1 linha e 2 colunas

# %%
# ver nosso eixo, agora ele eh uma lista com esses 2 elementos
ax
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
# interar entre as listas
# os axis vai assumindo os valores que esta dentro 
fig, ax = plt.subplots(nrows=1, ncols=2)

for axis in ax:
    axis.plot(x, y, "r")
    axis.set_title("test")

# %%
# outra forma de plotagem
fig, ax = plt.subplots(nrows=1, ncols=2)

for axis in ax:
    ax[0].plot(x, y, "red")
    ax[1].plot(x, y, "green")

# %%
# funcao que ajusta o layout

fig, ax = plt.subplots(nrows=1, ncols=2)

for axis in ax:
    axis.plot(x, y, "r")
plt.tight_layout()

# %%
# ajust no tamanho do grafic, # passa uma tupla com valores grandes 
fig, ax = plt.subplots(nrows=1, ncols=2, figsigze=(20, 10))

for axis in ax:
    axis.plot(x, y, "r")

# %%
# comportamento com multiplas linhas
fig, ax = plt.subplots(nrows=2, ncols=2)

# %%
# agora o eixo tem uma lista de lista
ax
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
# primeiro elemento eh a primeira linha
ax[0]
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
# primeiro elemento da segunda linha
ax[1][1]
# Out:
# <Axes: >

# %%
# Customizacao de graficos => METHOD DE EIXO
# Legendas, rotulos e titulos
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2)
ax.plot(x, x**3)

ax.set_title("Titulo")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")
# Out:
# Text(0, 0.5, 'Eixo Y')

# %%
# Customizacao de graficos => METHOD DE EIXO
# Legendas, rotulos e titulos
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")

ax.set_title("Titulo")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")

# para func precisa colocar legend, o plot procura o espaco mais vazio e add a legenda la
ax.legend()

# %%
# metodh loc legenda no grafic

# Customizacao de graficos => METHOD DE EIXO
# Legendas, rotulos e titulos
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")

ax.set_title("Titulo")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")

# para func precisa colocar legend, o plot procura o espaco mais vazio e add a legenda la
#ax.legend(loc=0) Melhor lugar
#ax.legend
ax.legend(loc=6) # fica mais abaixo

# %%
# colocar traco e outra linha b--
# metodh loc legenda no grafic

# Customizacao de graficos => METHOD DE EIXO
# Legendas, rotulos e titulos
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, "r--", label="x**2")
ax.plot(x, x**3, "g*-", label="x**3")

ax.set_title("Titulo")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")

# para func precisa colocar legend, o plot procura o espaco mais vazio e add a legenda la
#ax.legend(loc=0) Melhor lugar
#ax.legend
ax.legend(loc=6) # fica mais abaixo

# %%
# colocar cor com Hexa
# metodh loc legenda no grafic

# Customizacao de graficos => METHOD DE EIXO
# Legendas, rotulos e titulos
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2", color="#FF50AB")
ax.plot(x, x**3, "g*-", label="x**3")

ax.set_title("Titulo")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")

# para func precisa colocar legend, o plot procura o espaco mais vazio e add a legenda la
#ax.legend(loc=0) Melhor lugar
#ax.legend
ax.legend(loc=6) # fica mais abaixo

# %%
# sobrepor graficos - na mesma tabela - com transparencia


# colocar cor com Hexa
# metodh loc legenda no grafic

# Customizacao de graficos => METHOD DE EIXO
# Legendas, rotulos e titulos
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2", color="#FF50AB", alpha=0.3)
ax.plot(x, x**2.9, label="x**2", color="#FF50AB", alpha=1)
ax.plot(x, x**3, "g*-", label="x**3")

ax.set_title("Titulo")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")

# para func precisa colocar legend, o plot procura o espaco mais vazio e add a legenda la
#ax.legend(loc=0) Melhor lugar
#ax.legend
ax.legend(loc=6) # fica mais abaixo

# %%
# grafico com uma serie de plots diferentes
# Para alterar a largura da linha, podemos usar o argumento de palavras-chave `linewidth` ou` lw`. O estilo de linha pode ser selecionado usando os argumentos de palavras-chave `linestyle` ou` ls`:

fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25) # expessura da linha linewidth ou lw
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# Possiveis estilos de linha: ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-') # estilo da linha
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# Traços estilizados
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # Formato: comprimento da linha, comprimento do espaço, ...

# possíveis símbolos de marcador: marcador = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# tamanho e cor do marcador
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
# como faz para editar os eixos

# Podemos configurar os intervalos dos eixos usando os métodos `set_ylim` e` set_xlim` no objeto do eixo, ou `axis ('tight')` para obter automaticamente faixas de eixos "bem ajustados":

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
# 1 figuer com 3 eixos, utilizou a figsize passando uma tupla, com 3 eixos ao longo de uma linha

# add valores para essas informacoes
# primeiro acessar o eixo 0 
axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("intervalos de eixos padrão")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("eixos apertados")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60]) # limite do eixo y
axes[2].set_xlim([2, 5])
axes[2].set_title("distância personalizada dos eixos");

# %%
# Plots especiais

# grafico de pontos

plt.scatter(x, y)

# %%
# grafico de estograma
# gera numeros aleatorios => random

# gera numeros de 1 ate 1000 e gera 100 valores

from random import sample

data = sample(range(1, 1000), 100)

# %%
data # 100 valores de 1 ate 1000
# Out:
# [316,
#  358,
#  204,
#  27,
#  887,
#  45,
#  318,
#  110,
#  300,
#  51,
#  643,
#  33,
#  381,
#  38,
#  127,
#  76,
#  697,
#  89,
#  658,
#  777,
#  932,
#  828,
#  717,
#  458,
#  706,
#  288,
#  284,
#  114,
#  354,
#  580,
#  448,
#  332,
#  923,
#  993,
#  331,
#  18,
#  808,
#  152,
#  430,
#  188,
#  452,
#  637,
#  986,
#  749,
#  479,
#  197,
#  742,
#  736,
#  540,
#  853,
#  668,
#  240,
#  10,
#  621,
#  184,
#  119,
#  522,
#  585,
#  2,
#  651,
#  267,
#  727,
#  559,
#  233,
#  463,
#  973,
#  348,
#  935,
#  961,
#  844,
#  46,
#  454,
#  689,
#  626,
#  665,
#  968,
#  160,
#  417,
#  708,
#  544,
#  162,
#  836,
#  909,
#  655,
#  513,
#  781,
#  855,
#  183,
#  904,
#  685,
#  451,
#  364,
#  647,
#  813,
#  703,
#  494,
#  612,
#  77,
#  57,
#  625]

# %%
# agora criar um estograma com esses valores, passando o data

plt.hist(data)
# Out:
# (array([13., 11.,  6., 10., 10.,  7., 14., 11.,  8., 10.]),
#  array([  2. , 101.1, 200.2, 299.3, 398.4, 497.5, 596.6, 695.7, 794.8,
#         893.9, 993. ]),
#  <BarContainer object of 10 artists>)

# %%
# dois valores com uma variavel
# criar listas com desvio de padrao diferente, criando 100 valores nesse intervalo

# uma lista com 3 colunas com 100 valores

data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# %%
data
# Out:
# [array([-0.47165142, -0.10843458, -0.09310397, -1.84924498, -2.31527337,
#          0.13578227, -0.42197214, -1.22888559,  0.74016002, -0.23026303,
#          0.42830479,  0.6716606 , -0.11074109,  0.27164549,  0.96314269,
#         -0.49696779, -1.2781414 ,  2.22802523, -0.02143597, -1.08116816,
#         -1.25039013, -0.10957021, -0.68709197,  0.31942327,  0.85611651,
#         -2.44080313,  0.33723961,  0.28999276, -0.90096913, -0.42109694,
#         -1.46945582,  0.87602049, -0.06352679, -1.92313062, -1.19057125,
#          0.62193941,  2.43362959,  0.90507348,  0.72918605,  0.51243016,
#         -1.14591586, -0.10315361, -0.95066877,  1.95902576,  0.10054934,
#         -1.28729927, -1.35287847,  0.47355535,  1.49419032, -0.27770354,
#         -1.49666856,  1.15230575, -0.07983278,  0.9064959 ,  0.68279164,
#          0.14083901, -0.61992406, -0.65590839,  0.06020254,  2.2082787 ,
#          0.30851693,  1.85627105,  0.87091578,  0.62847185,  0.12258315,
# ...

# %%
len(data) # uma lista com 3 colunas com 100 valores
# Out:
# 3

# %%
# plotar os dados em grafico
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2238dfb42d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2238dfb4550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2238dfb4190>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2238dfb47d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2238dfb4910>,
# ...
#  'means': []}
